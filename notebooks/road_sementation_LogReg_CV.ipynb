# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
# import os,sys
# from PIL import Image

from helpers import *
from sklearn import linear_model
from sklearn.metrics import confusion_matrix

# %load_ext autoreload
# %autoreload 2

# %%
from sklearn import metrics, cross_validation
from sklearn.model_selection import KFold
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

from plots import cross_validation_visualization_f1score
from plots import cross_validation_visualization_rmse
# Out:
# c:\users\prisgdd\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
try: 
    import cv2
except: 
    import pip
    pip.main(['install', 'opencv-python'])
    import cv2

# %%
# Loaded a set of images
root_dir = "training/"
image_dir = root_dir + "images/"
gt_dir = root_dir + "groundtruth/"

files = os.listdir(image_dir)

n = len(files)
imgs = [load_image(image_dir + files[i]) for i in range(n)]
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]

print("Loading " + str(n) + " satellite + ground truth images")
# Out:
# Loading 100 satellite + ground truth images

# %%
# # Reduce dataset for tests
# imgs = imgs[0:10]
# gt_imgs = gt_imgs[0:10]
# len(imgs)

# %%
seed = 3
np.random.seed(seed)
imgs = np.random.permutation(imgs)
gt_imgs = np.random.permutation(gt_imgs)

# %%
patch_size = 16

kf = KFold(n_splits = 10)
kf.get_n_splits(imgs)
# Out:
# 10

# %%
import time

# %%
# Cs = np.arange(1e4, 1e4 + 1, 10000) 
lambdas = np.logspace(-5, 0, 10)
Cs = [np.ceil(1/lambda_) for lambda_ in lambdas]

acc_threshold =[]

accuracy_train_C = []
f1_score_train_C = []
mse_train_C = []
rmse_train_C = []

accuracy_test_C = []
f1_score_test_C = []
mse_test_C = []
rmse_test_C = []

accuracy_test_C_pp = []
f1_score_test_C_pp = []
mse_test_C_pp = []
rmse_test_C_pp = []

start_time_total = time.time()
for C in Cs:
    start_time_C = time.time()
    print("C = {}".format(C))

    accuracy_train_CV = []
    accuracy_test_CV = []
    mse_train_CV = []
    rmse_train_CV = []
    
    f1_score_train_CV = []
    f1_score_test_CV = []
    mse_test_CV = []
    rmse_test_CV = []
    
    accuracy_test_CV_pp = []
    f1_score_test_CV_pp = []
    mse_test_CV_pp = []
    rmse_test_CV_pp = []

    for ind, [train_index, test_index] in enumerate(kf.split(imgs)):

        #
        # Split dataset for Cross Validation
        #
        print("\n{}-th CV".format(ind+1))

        X_train = [imgs[ind] for ind in train_index]
        X_test = [imgs[ind] for ind in test_index]

        y_train = [gt_imgs[ind] for ind in train_index]
        y_test = [gt_imgs[ind] for ind in test_index]

        #
        # Crop images, extract features, features augmentation and standardization
        # For both train & test datasets
        # 
        X_train = [img_crop(X_train[i], patch_size, patch_size, step = 8) for i in range(len(train_index))]
        y_train = [img_crop(y_train[i], patch_size, patch_size, step = 8) for i in range(len(train_index))]
        X_test = [img_crop(X_test[i], patch_size, patch_size) for i in range(len(test_index))]
        y_test = [img_crop(y_test[i], patch_size, patch_size) for i in range(len(test_index))]        

        X_train = np.asarray([X_train[i][j] for i in range(len(X_train)) for j in range(len(X_train[i]))])
        X_test = np.asarray([X_test[i][j] for i in range(len(X_test)) for j in range(len(X_test[i]))])
        y_train = np.asarray([y_train[i][j] for i in range(len(y_train)) for j in range(len(y_train[i]))])
        y_test = np.asarray([y_test[i][j] for i in range(len(y_test)) for j in range(len(y_test[i]))])

        y_train = np.asarray([value_to_class(np.mean(y_train[i])) for i in range(y_train.shape[0])])
        y_test = np.asarray([value_to_class(np.mean(y_test[i])) for i in range(y_test.shape[0])])
#         print("Got all data in arrays!")

        # 
        # Balancing train data
        # 
        c0, c1 = 0, 0
        for i in range(len(y_train)):
            if y_train[i] == 0:
                c0 = c0 + 1
            else:
                c1 = c1 + 1
                
        min_c = min(c0, c1)
        idx0 = [i for i, j in enumerate(y_train) if j == 0]
        idx1 = [i for i, j in enumerate(y_train) if j == 1]
        new_indices = idx0[0:min_c] + idx1[0:min_c]
        X_train = X_train[new_indices]
        y_train = y_train[new_indices]
        
        
        
        X_train = np.asarray([ extract_features(X_train[i]) for i in range(len(X_train))])
        X_train = features_augmentation(X_train)
#         print("Train data ready!")

        X_test = np.asarray([ extract_features(X_test[i]) for i in range(len(X_test))])
        X_test = features_augmentation(X_test)
#         print("Test data ready!")
        print("All data balanced and ready!")
        print(X_train.shape)

        # 
        # Run logistic regression 
        # 
        logreg = linear_model.LogisticRegression(C=C, class_weight="balanced")
        logreg.fit(X_train, y_train)
#         print("Model fitted!")
        z_train = logreg.predict(X_train)
        z_test = logreg.predict(X_test)

        # 
        # Compute f1 score & accuracy using sklearn functions
        # 
        f1_score_train = f1_score(y_train, z_train, average='micro')
        accuracy_score_train = accuracy_score(y_train, z_train)
        mse_train = mean_squared_error(y_train, z_train)
        rmse_train = np.sqrt(mean_squared_error(y_train, z_train))
        
        f1_score_test = f1_score(y_test, z_test, average='macro')
        accuracy_score_test = accuracy_score(y_test, z_test)
        mse_test = mean_squared_error(y_test, z_test)
        rmse_test = np.sqrt(mean_squared_error(y_test, z_test))
        
        print("Train f1_score : {}".format(f1_score_train))
        print("Test f1_score : {}".format(f1_score_test))
        
        
        # 
        # Post processing on test dataset
        # 
        
        # Reshape prediction as matrix for each image
        z_reshaped = []
        num_patch_total = len(z_test)
        num_patch_by_img = num_patch_total // len(test_index)
        
        for i in range(0, num_patch_total, num_patch_by_img):
            z_crt = z_test[i : i + num_patch_by_img]
            z_reshaped.append(np.reshape(z_crt, [400 // 16, 400 // 16]))

        # Run post process 
        for ind, label_img in enumerate(z_reshaped):
            label_img = postprocess(label_img)
            z_reshaped[ind] = np.reshape(label_img, [z_crt.shape[0]])

        # Convert list as array
        z_test_pp = np.concatenate( z_reshaped , axis = 0 )
#         print("Postprocessing done!")

        f1_score_test_pp = f1_score(y_test, z_test_pp, average='micro')
        accuracy_score_test_pp = accuracy_score(y_test, z_test_pp)
        mse_test_pp = mean_squared_error(y_test, z_test_pp)
        rmse_test_pp = np.sqrt(mean_squared_error(y_test, z_test_pp))
        
        print("Test f1_score post processed : {}\n".format(f1_score_test_pp))
        
        # 
        # Store accuracy for train, test and test+PP
        # 
        f1_score_train_CV.append(f1_score_train)
        accuracy_train_CV.append(accuracy_score_train)
        mse_train_CV.append(mse_train)
        rmse_train_CV.append(rmse_train)

        f1_score_test_CV.append(f1_score_test)
        accuracy_test_CV.append(accuracy_score_test)
        mse_test_CV.append(mse_test)
        rmse_test_CV.append(rmse_test)
        
        f1_score_test_CV_pp.append(f1_score_test_pp)
        accuracy_test_CV_pp.append(accuracy_score_test_pp)
        mse_test_CV_pp.append(mse_test_pp)
        rmse_test_CV_pp.append(rmse_test_pp)
    

    print("Average train F1-score: {}".format(np.mean(f1_score_train_CV)))
    
    print("Average test F1-score: {}".format(np.mean(f1_score_test_CV)))
    print("Variance test F1-score: {}".format(np.std(f1_score_test_CV)))
    print("Min test F1-score: {} // Max test F1-score: {}\n".format(np.min(f1_score_test_CV), np.max(f1_score_test_CV)))
    
    print("Average test F1-score PP: {}".format(np.mean(f1_score_test_CV_pp)))
    print("Variance test F1-score PP: {}".format(np.std(f1_score_test_CV_pp)))
    print("Min test F1-score PP: {} // Max test F1-score PP: {}\n".format(np.min(f1_score_test_CV_pp), np.max(f1_score_test_CV_pp)))
    
    accuracy_train_C.append(np.mean(accuracy_train_CV))
    f1_score_train_C.append(np.mean(f1_score_train_CV))
    mse_train_C.append(np.mean(mse_train_CV))
    rmse_train_C.append(np.mean(rmse_train_CV))

    accuracy_test_C.append(np.mean(accuracy_test_CV))
    f1_score_test_C.append(np.mean(f1_score_test_CV))
    mse_test_C.append(np.mean(mse_test_CV))
    rmse_test_C.append(np.mean(rmse_test_CV))
    
    accuracy_test_C_pp.append(np.mean(accuracy_test_CV_pp))
    f1_score_test_C_pp.append(np.mean(f1_score_test_CV_pp))
    mse_test_C_pp.append(np.mean(mse_test_CV_pp))
    rmse_test_C_pp.append(np.mean(rmse_test_CV_pp))
    
    
    print("Time for C = %s --- %s seconds --- \n\n" % (C, time.time() - start_time_C))
print("T4otal time --- %s seconds --- \n\n" % (time.time() - start_time_total))
# Out:
# C = 100000.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5359064105658816
# Test f1_score : 0.4445412044553611
# Test f1_score post processed : 0.4864
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5281153345614954
# Test f1_score : 0.4696630888491353
# Test f1_score post processed : 0.55936
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5330291028069571
# Test f1_score : 0.45877783205602657
# Test f1_score post processed : 0.49712
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5212130136511677
# Test f1_score : 0.5096162246426976
# Test f1_score post processed : 0.56416
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.52087853929611
# Test f1_score : 0.4380450286168235
# Test f1_score post processed : 0.44848
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5280046674445741
# Test f1_score : 0.484473477416032
# Test f1_score post processed : 0.5184
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5253688595729908
# Test f1_score : 0.48904512753433615
# Test f1_score post processed : 0.54256
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5248255338403439
# Test f1_score : 0.5011168773929664
# Test f1_score post processed : 0.54784
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5232642549734691
# Test f1_score : 0.4489671150009653
# Test f1_score post processed : 0.48288
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5234227427276161
# Test f1_score : 0.47545880175549504
# Test f1_score post processed : 0.536
#
# Average train F1-score: 0.5264028459440606
# Average test F1-score: 0.47197047777198387
# Variance test F1-score: 0.023105362398370573
# Min test F1-score: 0.4380450286168235 // Max test F1-score: 0.5096162246426976
#
# Average test F1-score PP: 0.5183199999999999
# Variance test F1-score PP: 0.0362755146069632
# Min test F1-score PP: 0.44848 // Max test F1-score PP: 0.56416
#
# Time for C = 100000.0 --- 770.8909282684326 seconds ---
#
#
# C = 27826.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5357857167488534
# Test f1_score : 0.44073667686957785
# Test f1_score post processed : 0.4816
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5273970287491339
# Test f1_score : 0.46628173810052553
# Test f1_score post processed : 0.55264
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.531737558119511
# Test f1_score : 0.4493022931548577
# Test f1_score post processed : 0.48608
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5210137897581595
# Test f1_score : 0.5051739832727916
# Test f1_score post processed : 0.55904
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5215753726735468
# Test f1_score : 0.43830598091017225
# Test f1_score post processed : 0.45008
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5261659771578091
# Test f1_score : 0.48180669688022626
# Test f1_score post processed : 0.51552
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5243360527686166
# Test f1_score : 0.4942832458545124
# Test f1_score post processed : 0.55104
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5260524529681001
# Test f1_score : 0.503335216040978
# Test f1_score post processed : 0.54944
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.523177835007
# Test f1_score : 0.45024941704300603
# Test f1_score post processed : 0.4848
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5234141566782292
# Test f1_score : 0.4745434931233812
# Test f1_score post processed : 0.53536
#
# Average train F1-score: 0.526065594062896
# Average test F1-score: 0.4704018741250029
# Variance test F1-score: 0.024061810289144458
# Min test F1-score: 0.43830598091017225 // Max test F1-score: 0.5051739832727916
#
# Average test F1-score PP: 0.51656
# Variance test F1-score PP: 0.036483315638795775
# Min test F1-score PP: 0.45008 // Max test F1-score PP: 0.55904
#
# Time for C = 27826.0 --- 822.5809235572815 seconds ---
#
#
# C = 7743.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5360960722783544
# Test f1_score : 0.44014912242925497
# Test f1_score post processed : 0.48272
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5290449067892575
# Test f1_score : 0.46376586297380795
# Test f1_score post processed : 0.54464
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5323919407611504
# Test f1_score : 0.4485818407212405
# Test f1_score post processed : 0.4824
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5219665996812418
# Test f1_score : 0.5102538238837462
# Test f1_score post processed : 0.56368
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.52087853929611
# Test f1_score : 0.43894137832256463
# Test f1_score post processed : 0.45056
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5273239984441851
# Test f1_score : 0.4844570134972824
# Test f1_score post processed : 0.51856
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5261760111091824
# Test f1_score : 0.49059478866578643
# Test f1_score post processed : 0.5416
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5257391970205879
# Test f1_score : 0.5043037705611753
# Test f1_score post processed : 0.55296
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5235062308795824
# Test f1_score : 0.45424554353654256
# Test f1_score post processed : 0.48816
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.523457086925164
# Test f1_score : 0.47853977434939604
# Test f1_score post processed : 0.54336
#
# Average train F1-score: 0.5266580583184816
# Average test F1-score: 0.4713832918940796
# Variance test F1-score: 0.024668968634255967
# Min test F1-score: 0.43894137832256463 // Max test F1-score: 0.5102538238837462
#
# Average test F1-score PP: 0.5168639999999999
# Variance test F1-score PP: 0.03627212351103805
# Min test F1-score PP: 0.45056 // Max test F1-score PP: 0.56368
#
# Time for C = 7743.0 --- 819.0870785713196 seconds ---
#
#
# C = 2155.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5357598537880617
# Test f1_score : 0.441442378689387
# Test f1_score post processed : 0.48064
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5275237885983741
# Test f1_score : 0.46837153169146295
# Test f1_score post processed : 0.55424
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5324436025486482
# Test f1_score : 0.45012347868615454
# Test f1_score post processed : 0.48847999999999997
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5208318896819347
# Test f1_score : 0.5022647527059494
# Test f1_score post processed : 0.5536
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5211872629443416
# Test f1_score : 0.43916217221498977
# Test f1_score post processed : 0.45088
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5238764541565009
# Test f1_score : 0.47400714992267
# Test f1_score post processed : 0.50352
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5256552681826072
# Test f1_score : 0.487323840966278
# Test f1_score post processed : 0.54416
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5243034405944902
# Test f1_score : 0.5056700422587411
# Test f1_score post processed : 0.55248
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5218642515166704
# Test f1_score : 0.4491742962265765
# Test f1_score post processed : 0.4832
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5239722498883813
# Test f1_score : 0.46923597708120957
# Test f1_score post processed : 0.5264
#
# Average train F1-score: 0.5257418061900011
# Average test F1-score: 0.46867756204434186
# Variance test F1-score: 0.022826698209437238
# Min test F1-score: 0.43916217221498977 // Max test F1-score: 0.5056700422587411
#
# Average test F1-score PP: 0.5137599999999999
# Variance test F1-score PP: 0.03540861815999036
# Min test F1-score PP: 0.45088 // Max test F1-score PP: 0.55424
#
# Time for C = 2155.0 --- 813.2625687122345 seconds ---
#
#
# C = 600.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5362684920169661
# Test f1_score : 0.4424197200432928
# Test f1_score post processed : 0.48032
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.528791387090777
# Test f1_score : 0.4617950914774741
# Test f1_score post processed : 0.54304
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5334940588944378
# Test f1_score : 0.4582936977334834
# Test f1_score post processed : 0.49616
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5216807567043171
# Test f1_score : 0.5134129607531865
# Test f1_score post processed : 0.56304
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5209932080797389
# Test f1_score : 0.4380404946534766
# Test f1_score post processed : 0.44992
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5251493935857997
# Test f1_score : 0.4741227711941005
# Test f1_score post processed : 0.50528
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5250824509633745
# Test f1_score : 0.49054879021001097
# Test f1_score post processed : 0.54112
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5255216581681489
# Test f1_score : 0.5030940836039357
# Test f1_score post processed : 0.55136
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5229704270874743
# Test f1_score : 0.4598698832617656
# Test f1_score post processed : 0.49568
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5224439330975031
# Test f1_score : 0.476982937460123
# Test f1_score post processed : 0.54016
#
# Average train F1-score: 0.5262395765688538
# Average test F1-score: 0.47185804303908496
# Variance test F1-score: 0.02349989543553364
# Min test F1-score: 0.4380404946534766 // Max test F1-score: 0.5134129607531865
#
# Average test F1-score PP: 0.5166080000000001
# Variance test F1-score PP: 0.034592414428599796
# Min test F1-score PP: 0.44992 // Max test F1-score PP: 0.56304
#
# Time for C = 600.0 --- 744.7952809333801 seconds ---
#
#
# C = 167.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.535897789578951
# Test f1_score : 0.4445058128967372
# Test f1_score post processed : 0.4848
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5305153210404449
# Test f1_score : 0.4676139410046456
# Test f1_score post processed : 0.54752
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5327449629757189
# Test f1_score : 0.45729989003166016
# Test f1_score post processed : 0.49696
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5216287852539672
# Test f1_score : 0.5112031474055059
# Test f1_score post processed : 0.56256
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5201287818646908
# Test f1_score : 0.4398389843370141
# Test f1_score post processed : 0.45104
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5273063187298893
# Test f1_score : 0.4842747324034943
# Test f1_score post processed : 0.5184
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5242666203784065
# Test f1_score : 0.49158079977392444
# Test f1_score post processed : 0.54048
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5248864447190268
# Test f1_score : 0.4984557545881944
# Test f1_score post processed : 0.54416
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5232383289835284
# Test f1_score : 0.4576905050598887
# Test f1_score post processed : 0.49264
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5235343613696466
# Test f1_score : 0.4742037400743998
# Test f1_score post processed : 0.53456
#
# Average train F1-score: 0.5264147714894271
# Average test F1-score: 0.47266673075754645
# Variance test F1-score: 0.022364336138044796
# Min test F1-score: 0.4398389843370141 // Max test F1-score: 0.5112031474055059
#
# Average test F1-score PP: 0.517312
# Variance test F1-score PP: 0.03314826233756454
# Min test F1-score PP: 0.45104 // Max test F1-score PP: 0.56256
#
# Time for C = 167.0 --- 787.9094593524933 seconds ---
#
#
# C = 47.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5358374426704369
# Test f1_score : 0.44056442301139304
# Test f1_score post processed : 0.48448
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5286730778981527
# Test f1_score : 0.4627288209867205
# Test f1_score post processed : 0.54528
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5329085586361288
# Test f1_score : 0.46012924308263925
# Test f1_score post processed : 0.49568
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5219665996812418
# Test f1_score : 0.5130150815429579
# Test f1_score post processed : 0.56448
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.521204904295669
# Test f1_score : 0.4397797862030419
# Test f1_score post processed : 0.45216
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5259626604434072
# Test f1_score : 0.4800992720961026
# Test f1_score post processed : 0.51168
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5249783023780593
# Test f1_score : 0.48843024600391544
# Test f1_score post processed : 0.54352
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5260089451976123
# Test f1_score : 0.4963727348876536
# Test f1_score post processed : 0.5384
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.523177835007
# Test f1_score : 0.44552494621391325
# Test f1_score post processed : 0.47792
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5228989937150118
# Test f1_score : 0.4773337457664565
# Test f1_score post processed : 0.54032
#
# Average train F1-score: 0.526361731992272
# Average test F1-score: 0.47039782997947943
# Variance test F1-score: 0.02359816401557908
# Min test F1-score: 0.4397797862030419 // Max test F1-score: 0.5130150815429579
#
# Average test F1-score PP: 0.5153920000000001
# Variance test F1-score PP: 0.03464853843959366
# Min test F1-score PP: 0.45216 // Max test F1-score PP: 0.56448
#
# Time for C = 47.0 --- 690.9164164066315 seconds ---
#
#
# C = 13.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.535897789578951
# Test f1_score : 0.4424565645429426
# Test f1_score post processed : 0.4872
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5287998377473929
# Test f1_score : 0.46402472105660636
# Test f1_score post processed : 0.54784
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5315825727570174
# Test f1_score : 0.4488700606324928
# Test f1_score post processed : 0.48192
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5213429422770425
# Test f1_score : 0.5118258236307628
# Test f1_score post processed : 0.56368
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5208079738908
# Test f1_score : 0.43859586087956315
# Test f1_score post processed : 0.44928
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5260422191577384
# Test f1_score : 0.4809053312259704
# Test f1_score post processed : 0.51344
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5246918937684429
# Test f1_score : 0.48860411281502414
# Test f1_score post processed : 0.54368
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5251909991124415
# Test f1_score : 0.5044943625625661
# Test f1_score post processed : 0.55328
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.52354079886617
# Test f1_score : 0.4604277039532195
# Test f1_score post processed : 0.49616
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5233883985300684
# Test f1_score : 0.4762666438066624
# Test f1_score post processed : 0.53952
#
# Average train F1-score: 0.5261285425686065
# Average test F1-score: 0.471647118510581
# Variance test F1-score: 0.023948086777231793
# Min test F1-score: 0.43859586087956315 // Max test F1-score: 0.5118258236307628
#
# Average test F1-score PP: 0.5176000000000001
# Variance test F1-score PP: 0.03579575840794548
# Min test F1-score PP: 0.44928 // Max test F1-score PP: 0.56368
#
# Time for C = 13.0 --- 761.2982983589172 seconds ---
#
#
# C = 4.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5357512328011311
# Test f1_score : 0.44073667686957785
# Test f1_score post processed : 0.48096
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5302364493721162
# Test f1_score : 0.46410595613519345
# Test f1_score post processed : 0.54576
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5332529705527811
# Test f1_score : 0.45725824045133084
# Test f1_score post processed : 0.496
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.520901184949068
# Test f1_score : 0.5022766711952779
# Test f1_score post processed : 0.55312
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.5208873599717738
# Test f1_score : 0.4385846325369513
# Test f1_score post processed : 0.45088
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.526369293872211
# Test f1_score : 0.4797049680368609
# Test f1_score post processed : 0.51328
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5249696233292831
# Test f1_score : 0.4925941988721678
# Test f1_score post processed : 0.5472
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.525121386679661
# Test f1_score : 0.49713650376755336
# Test f1_score post processed : 0.54464
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5227716611645955
# Test f1_score : 0.44670672476497175
# Test f1_score post processed : 0.47968
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5233712264312944
# Test f1_score : 0.47650542154661435
# Test f1_score post processed : 0.54144
#
# Average train F1-score: 0.5263632389123915
# Average test F1-score: 0.46956099941764995
# Variance test F1-score: 0.02237451030962962
# Min test F1-score: 0.4385846325369513 // Max test F1-score: 0.5022766711952779
#
# Average test F1-score PP: 0.515296
# Variance test F1-score PP: 0.0344883108313527
# Min test F1-score PP: 0.45088 // Max test F1-score PP: 0.55312
#
# Time for C = 4.0 --- 812.6788494586945 seconds ---
#
#
# C = 1.0
#
# 1-th CV
# All data balanced and ready!
# (115996, 91)
# Train f1_score : 0.5358805476050899
# Test f1_score : 0.43869194788656973
# Test f1_score post processed : 0.47968
#
#
# 2-th CV
# All data balanced and ready!
# (118334, 91)
# Train f1_score : 0.5269575946051008
# Test f1_score : 0.4682356033553323
# Test f1_score post processed : 0.55584
#
#
# 3-th CV
# All data balanced and ready!
# (116140, 91)
# Train f1_score : 0.5332615808506974
# Test f1_score : 0.45407891629140024
# Test f1_score post processed : 0.49296
#
#
# 4-th CV
# All data balanced and ready!
# (115448, 91)
# Train f1_score : 0.5222351188413832
# Test f1_score : 0.4885433715220949
# Test f1_score post processed : 0.53072
#
#
# 5-th CV
# All data balanced and ready!
# (113370, 91)
# Train f1_score : 0.521099056187704
# Test f1_score : 0.4373840417370106
# Test f1_score post processed : 0.44944
#
#
# 6-th CV
# All data balanced and ready!
# (113124, 91)
# Train f1_score : 0.5261571373006613
# Test f1_score : 0.480287342518677
# Test f1_score post processed : 0.512
#
#
# 7-th CV
# All data balanced and ready!
# (115220, 91)
# Train f1_score : 0.5251865995486895
# Test f1_score : 0.49068381850073595
# Test f1_score post processed : 0.5448
#
#
# 8-th CV
# All data balanced and ready!
# (114922, 91)
# Train f1_score : 0.5253737317484903
# Test f1_score : 0.500888153766226
# Test f1_score post processed : 0.54688
#
#
# 9-th CV
# All data balanced and ready!
# (115714, 91)
# Train f1_score : 0.5228062291511831
# Test f1_score : 0.4442530761343246
# Test f1_score post processed : 0.47728
#
#
# 10-th CV
# All data balanced and ready!
# (116468, 91)
# Train f1_score : 0.5245561012466944
# Test f1_score : 0.47055435077256713
# Test f1_score post processed : 0.53168
#
# Average train F1-score: 0.5263513697085693
# Average test F1-score: 0.46736006224849386
# Variance test F1-score: 0.02173865675908328
# Min test F1-score: 0.4373840417370106 // Max test F1-score: 0.500888153766226
#
# Average test F1-score PP: 0.5121279999999999
# Variance test F1-score PP: 0.03387965903016144
# Min test F1-score PP: 0.44944 // Max test F1-score PP: 0.55584
#
# Time for C = 1.0 --- 827.545946598053 seconds ---
#
#
# T4otal time --- 7850.971253156662 seconds ---

# %%
cross_validation_visualization_f1score(lambdas, f1_score_train_C, f1_score_test_C, f1_score_test_C_pp)

# %%
cross_validation_visualization_rmse(lambdas, rmse_train_C, rmse_test_C)

# %%
X_test.shape

# %%
X_train[0].shape

# %%
confusion_matrix(y_test, z_test)
# Out:
# array([[2679, 2094],
#        [ 833,  644]], dtype=int64)

# %%
confusion_matrix(y_test, z_test_pp)
# Out:
# array([[2679, 2094],
#        [ 833,  644]], dtype=int64)
